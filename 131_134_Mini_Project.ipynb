# %% [markdown]
# #Name-Gauri Kardekar

# %% [markdown]
# #Roll no-131

# %% [markdown]
# #Name-Mayur Wakhare

# %% [markdown]
# #Roll no-134

# %% [markdown]
# #Problem Statement - Write a python program for a tourism company to facilitate creation of customized holidays and plan a trip for customers (considering factors like budget and facilities)

# %%
import numpy as np #importing numpy as np alies
import pandas as pd #importing pandas as pd alies
import matplotlib.pyplot as plt #importing matplotlib
import time #importing time to use sleep function to add time delay

print("___ __  __      __      __         ___         ")
print(" | |__||__|\  /|__ |   |__||__| \\// ||__||\/|")
print(" | |\  |  | \/ |__ |__ |\  |  | ||  ||  ||  |")#name of the tourism company

#tagline/quotation for tourism company
print("\n Adventures are the best way to learn. Start your own adventure with us. ")
print("Go for a solo trip. And travel far enough to find yourself.")
print("Travel with your family. Because travelling in company of our family is home in motion.")
print("SPECIAL OFFERS FOR SENIOR CITIZENS,SOLO TRAVELLERS AND FAMILIES!")
print("WELCOME TO TRAVEL RHYTHM!!!\n")

choice = 0
while(choice!=6):#while to iterate it until user wants to exit
    print("\nPlease select your desired Service :")
    time.sleep(1)#sleep call to delay it for () sec that is here 1 second
    print("$ press 1 to create your account ")
    print("$ press 2 to login to your account")
    print("$ press 3 to know favourite tourist spots of TRAVEL RHYTHM Explorers ")
    print("$ press 4 to customize your holidays")
    print("$ press 5 for tour guide")
    print("$ press 6 to EXIT")

    choice = int(input("\n Enter the service choice number you want:")) #input from user
    
    if choice == 1: #if and elif statements used to perform the desired operations as per entered choice
        class trip: #base class
            def _init_(self):
                self.user_name=""
                self.password=""
                self.DOB=""
                self.address=""
                self.phone_no=0
                self.adhar_no=0

            def creat_acc(self,user_name,password,DOB,address,phone_no,adhar_no): #attribute 1 of the base class
                self.user_name=user_name
                self.password=password
                self.DOB=DOB
                self.address=address
                self.phone_no=phone_no
                self.adhar_no=adhar_no

            def check_detail(self): #attribute 2
                print("\n Customer Name:",self.user_name)
                print("User-Password",self.password)
                print("\n Date of Birth ",self.DOB)
                print("\n Customer Address ",self.address)
                print("\n Phone Number",self.phone_no)
                print("\n Adhar Number",self.adhar_no)


        #INPUT FROM THE USER
        f_name = input("\n First name:") #first name of the user
        m_name = input("\n Middle name:") #middle name of the user
        l_name = input("\n Last name:")  #last name of the user
        name = f_name+" "+m_name+" "+l_name #string concatenation
        print("Full name:",name) #displaying output of full name
        time.sleep(1) #sleep call
        address = input("\n Enter your address : ") #address of user
         
        #INPUT FROM USER
        print("\n Enter your Date of Birth:") 
        birth_date = input("\n Date:") #input entry of birth date 
        month = input("\n Month:") #input entry of month
        year = input("\n year:") #input entry of year
        DOB = birth_date+"/"+month+"/"+year #string concatenation 
        print("Date of birth:",DOB) #displaying output of date of birth
        time.sleep(1)#sleep call
        adhaar = input("\n Enter your 12 digit adhaar no:")#input of adhaar number of the user
        mobile = input("\n Enter your 10 digit mobile number :") #mobile number of the user
        passport_no = input("Enter your passport number: ")#passport number of the user
        
        #LOGIN DETAILS OF USER
        print("\n Your login Details are :")
        userID = f_name + "tour"+birth_date #using string concatenation to create userID 
        print("User ID :",userID) #displaying userID 

        #creation of password
        slice = adhaar[:6] + mobile[:3]
        rev = l_name[::-1] #string reverse by using slicing 
        password = rev.lower()+slice
        print("Password :",password) #displaying password
        
        print("\n Your account has been created !!!!")    
        
    if choice==2: #if choice 2 is selected
        print("WELCOME! LOGIN TO YOUR ACCOUNT") 
        print("Please enter your login details:")
        username=input("Enter your UserID:")
        Password=input("Enter your password:")#INPUT FROM USER
        print("\n LOGIN SUCCESSFUL!") 
        
    if choice == 3: #if choice 3 is selected
         #favourite tourist spots pie chart
        print("You can choose one of these favourites places of tourists to visit!")
        print("\n...THE PIE CHART OF MOST VISITED TOURIST SPOTS IN YEAR 2019 BY TRAVEL RHYTHM EXPLORERS...")
        y = np.array([10,5,12,8,5,20,5,20,10,5])  #numerical array for pie chart
        mylabels = ["Paris", "Ladakh", "The Grand Canyon", "New Zealand","Great Barrier reef",
                    " London","Iceland","Maldives","New York","Phuket"]

        plt.pie(y, labels = mylabels) 
        plt.show() #to print the pie chart
        
    if choice == 4: #if choice 4 is selected
        print("Choices of countries to explore:")
        coun = pd.read_csv('countries.csv') #reading csv file
        print(coun) #printing the countries available to explore
        #INPUT FROM USER
        coun_name = input("\nPlease enter the name of country you want to explore:") 
        spot = input("\nLet us know any specific tourist spot you want to visit:")
        members = int(input("\nEnter number of members:")) #number of members who will be part of holiday
        details={}
        member={}
        group={}
        for i in range(members):#for loop to take input about information of people
            for j in range(1): #for loop to take information of each member
                print("\nDETAILS OF MEMBER",format(i+1))
                #INPUT FROM THE USER
                name = input("Enter full name:")
                fth_name = input("Enter father's full name:")
                age = int(input("Enter age:"))
                add = input("Enter permanent address:")
                mob_no = input("Enter mobile number:")
                adhaar_no = input("Enter adhaar number:")
                #storing the following information in dictionary
                details={'Name':name,'Father name':fth_name,'Age':age,'Permanent address':add,'mobile number':mob_no,'adhaar number':adhaar_no}
                member[j]=dict(details)
            group[i+1]=dict(member[j])
      #printing the entire dictionary
        print("Members Entered:-")
        for key in group:
            print("Member{0} = {1}". format(key,group[key]))
        
        time.sleep(1)#sleep call to delay it for () sec that is here 1 second
        
        #using csv and pandas to perform calculation of hotel bills and taxes 
        #for the total number of members in the trip
        print("\nThe total bill of hotel stay inclusive of tourist taxes and taxes of the country")
        tax = pd.read_csv('Taxes.csv') #reading csv file
        per = 0.17 #the percentage of total hotel bill included as taxes is 17%
        x = list(tax.Countries)
        
        for i in range(0,len(x)):
            if coun_name == x[i]: #the entered country's hotel bill and taxes
                break             #would be taken from from csv file for computation of taxes 
                                  #and total bill
        z = list(tax.iloc[i])
        
        #calculation of taxes
        #TAXES = 17%(hotel bill)+Tourist tax added to total bill
        #TOTAL BILL = HOTEL BILL + TAXES
        taxes = per*(z[1]) + (z[2]) 
        total_bill = (z[1] + taxes)*members
        #displaying total bill of the customer
        print("The total bill for the hotel stay inclusive of all taxes will be Rs.",total_bill)
        
    
    if choice == 5: # if choice 5 is selected
        print("The tour guides are:") #the tour guides available
        arr = np.array(["1) ADVENTURER","2) WONDERER","3) MULTILINGUISTIC SPECIALIST"]) #numpy array
        for k in arr:
            print(k) #displaying the categories of tour guide
        tour_guide =int(input("Enter tour guide number as specified above{1,2 or 3}:")) #input from user #tour_guide
        print("\nPlease enter the amount you can pay to a specific tour guide")
        print("Amount range from Rs.1000-Rs.5000")
        print("Increase in the amount paid will increase the facilities provided by tour guide")
        budget = int(input("Enter the amount you can pay on hour basis:")) #input from user 
                                                                          #amount to be paid
        
        if tour_guide == 1: #if entered choice is ADVENTURER
            if budget<=2500: #if amount paid is less than 2500
                print("\nName:Sameer , Age:25 yrs")
                print("- Enthusiatic,engaging,communicative tour guide")
                print("- Bus available for transportation ")
                print("- Covers all the special spots and landmarks")
            elif 2500<budget<=5000: #more than 2500
                print("\nName:Lisa , Age:26 yrs")
                print("- Punctual,energetic and funny tour guide")
                print("- Drives a private vehicle")
                print("- Spots as per the traveller's wish are also explored along with landmarks")
            else:
                print("Enter a valid choice")
                
        elif tour_guide == 2: #if entered choice is WONDERER
            if budget<=2500: #if amount paid is less than and equal to 2500
                print("\nName:Uma , Age :31 yrs")
                print("- Knowledgeable, history of every location")
                print("- Bus available for transportation ")
                print("- Covers all the special spots and landmarks")
            elif 2500<budget<=5000:#if amount paid more than 2500
                print("\nName:Ramesh , Age:30 yrs")
                print("- Knowdegable and tells about fun facts")
                print("- Geographic and Political knowledge along with historic")
                print("- Drives a private vehicle")
                print("- Spots as per the traveller's wish are also explored along with landmarks")
            else:
                print("Enter a valid choice")
                
        elif tour_guide == 3: #if choice entered  is MULTILINGUISTIC SPECIALIST
            if budget<=2500:#if amount paid is less than and equal to 2500
                print("\nName:Saurabh , Age :29 yrs")
                print("- Hindi,Marathi, Urdu,Gujarati,Rajasthani and many more languages are known")
                print("- Bus available for transportation ")
                print("- Covers all the special spots and landmarks")
                print("- Punctual and good art time managing")
            elif 2500<budget<=5000:#if amount paid is more than 2500
                print("\nName:Jolly , Age :32 yrs")
                print("Know the language of the tourist spot visiting to")
                print("Knows almost 13 languages")
                print("- Drives a private vehicle")
                print("- Spots as per the traveller's wish are also explored along with landmarks")
            else:
                print("Please enter a valid choice")
                
        else:
            print("Please enter a valid choice")

        
    if choice==6: #if choice 6 is selected
        print("You have logged out")
        time.sleep(1)#sleep call to delay it for () sec that is here 1 second
        print("\nTHANK YOU FOR USING OUR SERVICES")
        print("HOPE YOU VISIT BACK!")
        print("...HAVE A HAPPY AND SAFE JOURNEY!....")#end of the program
# Out:
# ___ __  __      __      __         ___
#  | |__||__|\  /|__ |   |__||__| \// ||__||\/|
#  | |\  |  | \/ |__ |__ |\  |  | ||  ||  ||  |
#
#  Adventures are the best way to learn. Start your own adventure with us.
# Go for a solo trip. And travel far enough to find yourself.
# Travel with your family. Because travelling in company of our family is home in motion.
# SPECIAL OFFERS FOR SENIOR CITIZENS,SOLO TRAVELLERS AND FAMILIES!
# WELCOME TO TRAVEL RHYTHM!!!
#
#
# Please select your desired Service :
# $ press 1 to create your account
# $ press 2 to login to your account
# $ press 3 to know favourite tourist spots of TRAVEL RHYTHM Explorers
# $ press 4 to customize your holidays
# $ press 5 for tour guide
# $ press 6 to EXIT
#
#  Enter the service choice number you want:1
#
#  First name:Emma
#
#  Middle name:Steve
#
#  Last name:Rogers
# Full name: Emma Steve Rogers
#
#  Enter your address : Pearls Residency,Andheri,Mumbai
#
#  Enter your Date of Birth:
#
#  Date:20
#
#  Month:06
#
# ...
